# %%
import pandas as pd
from rdkit import Chem

from stereomolgraph import StereoMolGraph
from stereomolgraph.experimental._pandas_patcher import patchPandas
from stereomolgraph.experimental.sym_num import topological_symmetry_number
from stereomolgraph.ipython import View2D

View2D.show_h = True
View2D.show_atom_numbers = False
View2D.generate_bond_orders = False

patchPandas()

# %%
smiles = [
    "C1[C@H]2[C@H]3[C@@H]4[C@H]1[C@@H]4[C@@H]23",
    "[C@@H]12[C@H]3[C@H]4[C@@H]1[C@@H]5[C@H]4[C@H]3[C@H]25",
    "[C@@]12(CCC3)[C@@]3(CCC4)[C@@]4(CCC5)[C@]65[C@]1(CCC2)CCC6",
    "[C@]12(CCC3)[C@]3(CCC4)[C@]4(CCC5)[C@@]65[C@@]1(CCC2)CCC6",
    "[C@@]12(CCC3)[C@@]3(CCC4)[C@@]4(CCC5)[C@]65[C@@]1(CCC2)CCC6",
    "[C@@]12(CCC3)[C@]3(CCC4)[C@@]4(CCC5)[C@]65[C@@]1(CCC2)CCC6",
    "F[C@H]1C[C@@H](F)C[C@@H](F)C1",
    "F[C@@H]1C[C@@H](F)C[C@@H](F)C1",
    "F[C@H]1[C@@H](F)[C@@H](F)[C@H](F)[C@H](F)[C@H]1F",
    "F[C@H]1[C@@H](F)[C@H](F)[C@H](F)[C@H](F)[C@H]1F",
    "F[C@H]1[C@@H](F)C[C@@H](F)[C@@H](F)C1",
    "F[C@H]1[C@H](F)C[C@@H](F)[C@H](F)C1",
    "F[C@H]1[C@H](F)C[C@H](F)[C@@H](F)C1",
    "F[C@H]1[C@@H](F)C[C@H](F)[C@H](F)C1",
    "F[C@H]1[C@@H](F)[C@@H](F)[C@H](F)[C@H](F)[C@H]1F",
]

# %%
rows = []
for smiles_string in smiles:
    rdmol = Chem.MolFromSmiles(smiles_string, sanitize=False)
    rdmol.UpdatePropertyCache(strict=True)
    rdmol = Chem.AddHs(rdmol)
    Chem.SanitizeMol(rdmol)

    graph = StereoMolGraph.from_rdmol(rdmol, stereo_complete=True)
    rows.append(
        {
            "StereoMolGraph": graph,
            "top_sym_num": topological_symmetry_number(graph),
            "input_smiles": smiles_string,
        }
    )

df_smiles_symmetry = pd.DataFrame(rows)
df_smiles_symmetry
# Out:
#                                        StereoMolGraph  top_sym_num  \
# 0   StereoMolGraph\nAtoms\n(0 C) (1 C) (2 C) (3 C)...            2
# 1   StereoMolGraph\nAtoms\n(0 C) (1 C) (2 C) (3 C)...           24
# 2   StereoMolGraph\nAtoms\n(0 C) (1 C) (2 C) (3 C)...           10
# 3   StereoMolGraph\nAtoms\n(0 C) (1 C) (2 C) (3 C)...           10
# 4   StereoMolGraph\nAtoms\n(0 C) (1 C) (2 C) (3 C)...            2
# 5   StereoMolGraph\nAtoms\n(0 C) (1 C) (2 C) (3 C)...            2
# 6   StereoMolGraph\nAtoms\n(0 F) (1 C) (2 C) (3 C)...            3
# 7   StereoMolGraph\nAtoms\n(0 F) (1 C) (2 C) (3 C)...            1
# 8   StereoMolGraph\nAtoms\n(0 F) (1 C) (2 C) (3 F)...            1
# 9   StereoMolGraph\nAtoms\n(0 F) (1 C) (2 C) (3 F)...            2
# 10  StereoMolGraph\nAtoms\n(0 F) (1 C) (2 C) (3 F)...            2
# 11  StereoMolGraph\nAtoms\n(0 F) (1 C) (2 C) (3 F)...            4
# 12  StereoMolGraph\nAtoms\n(0 F) (1 C) (2 C) (3 F)...            2
# 13  StereoMolGraph\nAtoms\n(0 F) (1 C) (2 C) (3 F)...            2
# 14  StereoMolGraph\nAtoms\n(0 F) (1 C) (2 C) (3 F)...            1
#
#                                          input_smiles
# 0          C1[C@H]2[C@H]3[C@@H]4[C@H]1[C@@H]4[C@@H]23
# 1   [C@@H]12[C@H]3[C@H]4[C@@H]1[C@@H]5[C@H]4[C@H]3...
# 2   [C@@]12(CCC3)[C@@]3(CCC4)[C@@]4(CCC5)[C@]65[C@...
# 3   [C@]12(CCC3)[C@]3(CCC4)[C@]4(CCC5)[C@@]65[C@@]...
# 4   [C@@]12(CCC3)[C@@]3(CCC4)[C@@]4(CCC5)[C@]65[C@...
# 5   [C@@]12(CCC3)[C@]3(CCC4)[C@@]4(CCC5)[C@]65[C@@...
# 6                       F[C@H]1C[C@@H](F)C[C@@H](F)C1
# 7                      F[C@@H]1C[C@@H](F)C[C@@H](F)C1
# 8    F[C@H]1[C@@H](F)[C@@H](F)[C@H](F)[C@H](F)[C@H]1F
# 9     F[C@H]1[C@@H](F)[C@H](F)[C@H](F)[C@H](F)[C@H]1F
# 10              F[C@H]1[C@@H](F)C[C@@H](F)[C@@H](F)C1
# 11                F[C@H]1[C@H](F)C[C@@H](F)[C@H](F)C1
# 12                F[C@H]1[C@H](F)C[C@H](F)[C@@H](F)C1
# 13                F[C@H]1[C@@H](F)C[C@H](F)[C@H](F)C1
# 14   F[C@H]1[C@@H](F)[C@@H](F)[C@H](F)[C@H](F)[C@H]1F
